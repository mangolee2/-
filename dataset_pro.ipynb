# %%
import pandas as pd

# %%
df=pd.read_table('C:/Users/seohe/OneDrive/바탕 화면/Thesis/dataset_tsmc2014/NYC.txt')

# %%
df
# Out:
#         User ID                  Venue ID         Venue category ID  \
# 0           470  49bbd6c0f964a520f4531fe3  4bf58dd8d48988d127951735
# 1           979  4a43c0aef964a520c6a61fe3  4bf58dd8d48988d1df941735
# 2            69  4c5cc7b485a1e21e00d35711  4bf58dd8d48988d103941735
# 3           395  4bc7086715a7ef3bef9878da  4bf58dd8d48988d104941735
# 4            87  4cf2c5321d18a143951b5cec  4bf58dd8d48988d1cb941735
# ...         ...                       ...                       ...
# 227423      688  3fd66200f964a52000e71ee3  4bf58dd8d48988d1e7931735
# 227424      560  4bca32ff0687ef3be789dbcc  4bf58dd8d48988d16c941735
# 227425      945  50a77716e4b0b5a9492f6f56  4bf58dd8d48988d103941735
# 227426      671  4514efe0f964a520e7391fe3  4bf58dd8d48988d11d941735
# 227427      942  4a1e0ca0f964a520bf7b1fe3  4bf58dd8d48988d116941735
#
#         Venue category name   Latitude  Longitude Timezone offset in minutes  \
# ...

# %%
# Tdf=pd.read_table('C:/Users/seohe/OneDrive/바탕 화면/Thesis/dataset_tsmc2014/TKY.txt')

# %%
# Tdf

# %%
print(df['Venue category name'].str.contains('Caf?'))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 227423    False
# 227424    False
# 227425    False
# 227426    False
# 227427    False
# Name: Venue category name, Length: 227428, dtype: bool

# %%
if df['Venue category name'].str.contains('Caf?')==True:
    print(df.index())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-ad767fceae8d> in <module>
# ----> 1 if df['Venue category name'].str.contains('Caf?')==True:
#       2     print(df.index())
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df1=pd.DataFrame(df['Venue category name'].str.split('?', 2).tolist())

# %%
df1.head(20)
# Out:
#     User ID                  Venue ID         Venue category ID  \
# 0       470  49bbd6c0f964a520f4531fe3  4bf58dd8d48988d127951735
# 1       979  4a43c0aef964a520c6a61fe3  4bf58dd8d48988d1df941735
# 2        69  4c5cc7b485a1e21e00d35711  4bf58dd8d48988d103941735
# 3       395  4bc7086715a7ef3bef9878da  4bf58dd8d48988d104941735
# 4        87  4cf2c5321d18a143951b5cec  4bf58dd8d48988d1cb941735
# 5       484  4b5b981bf964a520900929e3  4bf58dd8d48988d118951735
# 6       642  4ab966c3f964a5203c7f20e3  4bf58dd8d48988d1e0931735
# 7       292  4d0cc47f903d37041864bf55  4bf58dd8d48988d12b951735
# 8       428  4ce1863bc4f6a35d8bd2db6c  4bf58dd8d48988d103941735
# 9       877  4be319b321d5a59352311811  4bf58dd8d48988d10a951735
# 10       87  4d8263a73e916dcb8edd80d2  4bf58dd8d48988d155941735
# 11      625  4ab5320cf964a5202b7320e3  4bf58dd8d48988d122951735
# 12      691  4cb50d599c7ba35de0ef8706  4bf58dd8d48988d104941735
# 13      116  4c0ab56f7e3fc9288c1df482  4f04afc02fb6e1c99f3db0bc
# ...
